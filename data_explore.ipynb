# %% [markdown]
# Pandas Method

# %%
# Load package
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %%
# Import data
excel_file_path = 'Financial Sample.xlsx'
df = pd.read_excel(excel_file_path)
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
# Number of row and column of dataset
df.shape
# Out:
# (700, 16)

# %%
# How many column and their name? 16
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        ' Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
# Describe quantitative variables
df.describe()
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   700.000000           700.000000  700.000000  7.000000e+02
# mean   1608.294286            96.477143  118.428571  1.827594e+05
# std     867.427859           108.602612  136.775515  2.542623e+05
# min     200.000000             3.000000    7.000000  1.799000e+03
# 25%     905.000000             5.000000   12.000000  1.739175e+04
# 50%    1542.500000            10.000000   20.000000  3.798000e+04
# 75%    2229.125000           250.000000  300.000000  2.790250e+05
# max    4492.500000           260.000000  350.000000  1.207500e+06
#
#            Discounts         Sales           COGS         Profit  \
# count     700.000000  7.000000e+02     700.000000     700.000000
# mean    13150.354629  1.696091e+05  145475.211429   24133.860371
# std     22962.928775  2.367263e+05  203865.506118   42760.626563
# min         0.000000  1.655080e+03     918.000000  -40617.500000
# ...

# %%
# Info about variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount Band        700 non-null    object
#  4   Units Sold           700 non-null    float64
#  5   Manufacturing Price  700 non-null    int64
#  6   Sale Price           700 non-null    int64
#  7   Gross Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9    Sales               700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    float64
#  12  Date                 700 non-null    datetime64[ns]
#  13  Month Number         700 non-null    int64
#  14  Month Name           700 non-null    object
# ...

# %%
# Unique value for 'Segment'
# There are 5 unique values for 'Segment variable'
df['Segment'].unique()
# Out:
# array(['Government', 'Midmarket', 'Channel Partners', 'Enterprise',
#        'Small Business'], dtype=object)

# %%
# Barchart for 'Segment'
# s = df.Segment.value_counts(normalize=True).plot(kind='pie')
s = df.Segment.value_counts().plot(kind='bar',color=['black','red','blue','green','yellow'])
# s = df.Segment.value_counts(normalize=True).plot(kind='bar',color=['black','red','blue','green','yellow'])

# %%
# Unique value for 'Country'
# There are 5 countries
df['Country'].unique()
# Out:
# array(['Canada', 'Germany', 'France', 'Mexico',
#        'United States of America'], dtype=object)

# %%
# Plot for Country:
# df.Country.value_counts().plot(kind='bar')
df.Country.value_counts()
# Out:
# Canada                      140
# Germany                     140
# France                      140
# Mexico                      140
# United States of America    140
# Name: Country, dtype: int64

# %%
# Pivot table for Country:
pivot_1 = pd.pivot_table(df,index='Country')
pivot_1
# Out:
#                                   Sales           COGS     Discounts  \
# Country
# Canada                    177768.963464  152560.185714  14603.632964
# France                    173958.373429  146951.082143  12339.301571
# Germany                   167895.291571  141606.800000  10115.190571
# Mexico                    149638.229357  128870.207143  12697.020643
# United States of America  178784.501179  157387.782143  15996.627393
#
#                             Gross Sales  Manufacturing Price  Month Number  \
# Country
# Canada                    192372.596429            93.928571           7.9
# France                    186297.675000            95.528571           7.9
# Germany                   178010.482143            95.500000           7.9
# Mexico                    162335.250000            95.671429           7.9
# United States of America  194781.128571           101.757143           7.9
#
#                                 Profit  Sale Price   Units Sold     Year
# ...

# %%
# Pivot table for Segment x Country:
pivot_2 = pd.pivot_table(df,index=['Segment','Country'])
pivot_2
# Out:
#                                                    Sales           COGS  \
# Segment          Country
# Channel Partners Canada                     24558.207000    6609.300000
#                  France                     18604.518000    5025.450000
#                  Germany                    16821.294000    4453.350000
#                  Mexico                     11718.954000    3174.450000
#                  United States of America   18326.709000    4926.975000
# Enterprise       Canada                    198374.562500  204450.000000
#                  France                    194544.531250  199332.000000
#                  Germany                   204341.312500  209415.000000
#                  Mexico                    165794.062500  171828.000000
#                  United States of America  217530.250000  226287.000000
# Government       Canada                    179020.608667  141379.416667
#                  France                    202129.712000  156964.458333
# ...

# %%
# Pivot table for product x country:
pivot_3 = pd.pivot_table(df,index=['Product','Country'], aggfunc='sum')
pivot_3
# Out:
#                                           Sales       COGS   Discounts  \
# Product   Country
# Amarilla  Canada                    3855765.875  3208904.5  308917.625
#           France                    4016427.130  3348559.5  302236.870
#           Germany                   3960250.260  3348113.0  162954.240
#           Mexico                    3077555.390  2578944.0  225640.610
#           United States of America  2837117.405  2448491.0  290414.095
# Carretera Canada                    2610204.340  2174099.0  215649.160
#           France                    3423321.895  3034457.0  264507.605
#           Germany                   3062340.680  2692666.0  244035.320
#           Mexico                    2879601.420  2485933.0  232409.580
#           United States of America  1839839.550  1601348.0  165610.950
# Montana   Canada                    2711919.030  2390052.0  270195.470
#           France                    3527382.370  3066144.0  315833.630
# ...

# %%
type(pivot_3)
# Out:
# pandas.core.frame.DataFrame

# %%
# Sort data but just show COGS column:
pivot_3 = pd.pivot_table(df,index=['Product','Country'], values='COGS', aggfunc='sum')
pivot_3
# Out:
#                                          COGS
# Product   Country
# Amarilla  Canada                    3208904.5
#           France                    3348559.5
#           Germany                   3348113.0
#           Mexico                    2578944.0
#           United States of America  2448491.0
# Carretera Canada                    2174099.0
#           France                    3034457.0
#           Germany                   2692666.0
#           Mexico                    2485933.0
#           United States of America  1601348.0
# Montana   Canada                    2390052.0
#           France                    3066144.0
#           Germany                   3006606.0
#           Mexico                    1603640.0
#           United States of America  3209605.0
# Paseo     Canada                    6346503.0
#           France                    4759002.5
#           Germany                   4485398.0
#           Mexico                    6699080.0
# ...

# %%
# Bar chart for sum of Products by countries
pivot_3 = pd.pivot_table(df,index=['Product'], values='COGS', aggfunc='sum').plot(kind='bar', color='maroon')
pivot_3
# Out:
# <AxesSubplot:xlabel='Product'>

# %%
pivot_3 = pd.pivot_table(df,index=['Country','Discount Band'], values='Manufacturing Price', aggfunc='sum')
pivot_3
# Out:
#                                         Manufacturing Price
# Country                  Discount Band
# Canada                   High                          5401
#                          Low                           2256
#                          Medium                        4805
#                          None                           688
# France                   High                          4841
#                          Low                           2162
#                          Medium                        4963
#                          None                          1408
# Germany                  High                          3656
#                          Low                           3290
#                          Medium                        4990
#                          None                          1434
# Mexico                   High                          5393
#                          Low                           3124
# ...

# %%
pivot_3 = pd.pivot_table(df,index=['Country'], values='Profit', aggfunc='sum').plot(kind='bar')
pivot_3
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
# Filter data:

# %%
# Show first 10 rows and all columns:
df.head(10)
# Out:
#             Segment  Country    Product Discount Band  Units Sold  \
# 0        Government   Canada  Carretera          None      1618.5
# 1        Government  Germany  Carretera          None      1321.0
# 2         Midmarket   France  Carretera          None      2178.0
# 3         Midmarket  Germany  Carretera          None       888.0
# 4         Midmarket   Mexico  Carretera          None      2470.0
# 5        Government  Germany  Carretera          None      1513.0
# 6         Midmarket  Germany    Montana          None       921.0
# 7  Channel Partners   Canada    Montana          None      2518.0
# 8        Government   France    Montana          None      1899.0
# 9  Channel Partners  Germany    Montana          None      1545.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                    3          20      32370.0        0.0   32370.0
# 1                    3          20      26420.0        0.0   26420.0
# ...

# %%
# Show row 0 to row 14 and all columns
df.loc[0:15, :]
# Out:
#              Segment                   Country    Product Discount Band  \
# 0         Government                    Canada  Carretera          None
# 1         Government                   Germany  Carretera          None
# 2          Midmarket                    France  Carretera          None
# 3          Midmarket                   Germany  Carretera          None
# 4          Midmarket                    Mexico  Carretera          None
# 5         Government                   Germany  Carretera          None
# 6          Midmarket                   Germany    Montana          None
# 7   Channel Partners                    Canada    Montana          None
# 8         Government                    France    Montana          None
# 9   Channel Partners                   Germany    Montana          None
# 10         Midmarket                    Mexico    Montana          None
# 11        Enterprise                    Canada    Montana          None
# ...

# %%
# Show row 0 to 9 with 2 columns: 'Segment' and 'Units Sold'
df.loc[0:10, ['Segment','Units Sold']]
# Out:
#              Segment  Units Sold
# 0         Government      1618.5
# 1         Government      1321.0
# 2          Midmarket      2178.0
# 3          Midmarket       888.0
# 4          Midmarket      2470.0
# 5         Government      1513.0
# 6          Midmarket       921.0
# 7   Channel Partners      2518.0
# 8         Government      1899.0
# 9   Channel Partners      1545.0
# 10         Midmarket      2470.0

# %%
# Show all rows, column: from 'Segment' through 'Units Sold'
df.loc[:,'Segment':'Units Sold']
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold
# 0        1618.5
# 1        1321.0
# 2        2178.0
# 3         888.0
# ...

# %%
# Summarized statistics for numeric variables
df.describe()
# Out:
#         Units Sold  Manufacturing Price  Sale Price   Gross Sales  \
# count   700.000000           700.000000  700.000000  7.000000e+02
# mean   1608.294286            96.477143  118.428571  1.827594e+05
# std     867.427859           108.602612  136.775515  2.542623e+05
# min     200.000000             3.000000    7.000000  1.799000e+03
# 25%     905.000000             5.000000   12.000000  1.739175e+04
# 50%    1542.500000            10.000000   20.000000  3.798000e+04
# 75%    2229.125000           250.000000  300.000000  2.790250e+05
# max    4492.500000           260.000000  350.000000  1.207500e+06
#
#            Discounts         Sales           COGS         Profit  \
# count     700.000000  7.000000e+02     700.000000     700.000000
# mean    13150.354629  1.696091e+05  145475.211429   24133.860371
# std     22962.928775  2.367263e+05  203865.506118   42760.626563
# min         0.000000  1.655080e+03     918.000000  -40617.500000
# ...

# %%
# How many country in dataset? 5
df.Country.unique()
# Out:
# array(['Canada', 'Germany', 'France', 'Mexico',
#        'United States of America'], dtype=object)

# %%
# Sort data for Canada
df[df.Country=='Canada']
# Out:
#               Segment Country    Product Discount Band  Units Sold  \
# 0          Government  Canada  Carretera          None      1618.5
# 7    Channel Partners  Canada    Montana          None      2518.0
# 11         Enterprise  Canada    Montana          None      2665.5
# 14         Enterprise  Canada    Montana          None       345.0
# 16         Government  Canada      Paseo          None       292.0
# ..                ...     ...        ...           ...         ...
# 671         Midmarket  Canada      Paseo          High      1614.0
# 674         Midmarket  Canada      Paseo          High      2559.0
# 688        Government  Canada        VTT          High       865.5
# 692        Enterprise  Canada        VTT          High      2954.0
# 698        Government  Canada      Paseo          High       723.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# 0                      3          20      32370.0       0.00   32370.00
# ...

# %%
# Sort data for Canada but using 'loc'
canada = df.loc[df.Country=='Canada', :]
canada
# Out:
#               Segment Country    Product Discount Band  Units Sold  \
# 0          Government  Canada  Carretera          None      1618.5
# 7    Channel Partners  Canada    Montana          None      2518.0
# 11         Enterprise  Canada    Montana          None      2665.5
# 14         Enterprise  Canada    Montana          None       345.0
# 16         Government  Canada      Paseo          None       292.0
# ..                ...     ...        ...           ...         ...
# 671         Midmarket  Canada      Paseo          High      1614.0
# 674         Midmarket  Canada      Paseo          High      2559.0
# 688        Government  Canada        VTT          High       865.5
# 692        Enterprise  Canada        VTT          High      2954.0
# 698        Government  Canada      Paseo          High       723.0
#
#      Manufacturing Price  Sale Price  Gross Sales  Discounts      Sales  \
# 0                      3          20      32370.0       0.00   32370.00
# ...

# %%
# Sort data for Canada with some columns:
filt_1 = df.loc[df.Country=='Canada', ['Segment','Product','Units Sold','Profit']]
filt_1
# Out:
#               Segment    Product  Units Sold    Profit
# 0          Government  Carretera      1618.5  16185.00
# 7    Channel Partners    Montana      2518.0  22662.00
# 11         Enterprise    Montana      2665.5  13327.50
# 14         Enterprise    Montana       345.0   1725.00
# 16         Government      Paseo       292.0   2920.00
# ..                ...        ...         ...       ...
# 671         Midmarket      Paseo      1614.0   4438.50
# 674         Midmarket      Paseo      2559.0   7037.25
# 688        Government        VTT       865.5   6058.50
# 692        Enterprise        VTT      2954.0 -40617.50
# 698        Government      Paseo       723.0    686.85
#
# [140 rows x 4 columns]

# %%
# First 10 rows of filt_1
filt_1.head(10)
# Out:
#              Segment    Product  Units Sold    Profit
# 0         Government  Carretera      1618.5   16185.0
# 7   Channel Partners    Montana      2518.0   22662.0
# 11        Enterprise    Montana      2665.5   13327.5
# 14        Enterprise    Montana       345.0    1725.0
# 16        Government      Paseo       292.0    2920.0
# 18  Channel Partners      Paseo      2518.0   22662.0
# 26        Government      Paseo      1725.0  155250.0
# 28         Midmarket      Paseo      2152.0   10760.0
# 29        Government      Paseo      1817.0   18170.0
# 37        Enterprise       Velo       345.0    1725.0

# %%
# Sort data for Canada but using 'loc' and with just 'Segment' column
canada_1 = df.loc[df.Country=='Canada', 'Segment']
canada_1
# Out:
# 0            Government
# 7      Channel Partners
# 11           Enterprise
# 14           Enterprise
# 16           Government
#              ...
# 671           Midmarket
# 674           Midmarket
# 688          Government
# 692          Enterprise
# 698          Government
# Name: Segment, Length: 140, dtype: object

# %%
# 'iloc' method
# Filter row and select column by integer position, here we selected first 4 columns, number '4' is excluded
df.iloc[:,0:4]
# Out:
#               Segment                   Country    Product Discount Band
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
# [700 rows x 4 columns]
